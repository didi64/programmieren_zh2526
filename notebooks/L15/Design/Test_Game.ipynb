# %% [markdown]
# ### Spielkomponente testen

# %%
import game


game.new_game()
game.state

# %%
game.move(0, 1)
game.state

# %%
game.move(1, 0)
game.state

# %%
game.move(0, -1)
game.move(1, 0)
game.state

# %%
game.move(0, 1)
game.state
