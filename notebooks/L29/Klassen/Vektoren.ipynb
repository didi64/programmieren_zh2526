# %% [markdown]
# ### Ausbau der Klasse `Vector`
#
# Im Moment können wir das Skalarprodukt zweier Vektoren `v` und `w` berechnen.
# Wir möchten aber auch einen Vektor mit einer Zahl von recht  und links multiplizieren können,
# und `v*3` und `3*v`.
#
# Im 1. Fall wird `v.__mul__(3)`, also `Vector.__mul__(v, 3)` aufgerufen. Hier können wir
# in dieser Funktion den Typ des 2. Argumentes mit `isinstance` testen:
#
# ```python
# class Vector:
#     def __add__(self, other):
#         if isinstance(other, Vector):
#             # berechene Skalarprodukt
#         elif isinsance(other, (int, float)):
#             # streckce den Vektor
#         else:
#             return NotImlemented
# ```
#
# Im 2. Fall `3*v` wird `int.__mul(3, v)` und wirft einen TypeError.
# Das können wir beheben, indem wir `Vector.__rmul__` implementieren.
#
#
# Seien `v` und `w` z.B. Instanzen der Klasse `Vector`.
# Wenn Python den Ausdruck `v + w` auswertet, läuft folgende Sequenz ab:
#
#    1. Python versucht, `v.__mul__(w)` aufzurufen.
#    2. Falls `Vector` keine `__mul__`-Methode besitzt oder `v.__mul__(w)` den Wert `NotImplemented` zurückgibt, wertet Python den rechten Operanden `w` aus.
#    3. Danach ruft Python `w.__rmul__(v)` auf.
#    4. Wenn auch das `NotImplemented` zurückgibt oder nicht existiert, wirft Python einen `TypeError`.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __mul__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x+other.x, self.y+self.y)
        elif isinstance(other, (int, float)):
            return Vector(other*self.x, other*self.y)
        else:
            return NotImplemented


    def __repr__(self):
        return f'Vector({self.x}, {self.y})'

# %%
v = Vector(1, 2)
v*v, v*3

# %%
3*v

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __mul__(self, other):
        if isinstance(other, Vector):
            return self.x+other.x + self.y+self.y
        elif isinstance(other, (int, float)):
            return Vector(other*self.x, other*self.y)
        else:
            return NotImplemented

    def __rmul__(self, z):
        return self * z


    def __repr__(self):
        return f'Vector({self.x}, {self.y})'

# %%
v = Vector(1, 2)
v*v, v*3, 3*v

# %% [markdown]
# ### Aufgabe
# Erweitere die Klasse `Vektor`, so dass folgende Operationen für Vektoren `v` und `w` implementiert sind:
# - `v + w`
# - `3*v` und `v*3` (siehe oben)
# - `-v` (implementiere `__neg__(self)`)
#   suche z.B. im KI-Modus nach "Wie kann ich in Python die Operation - (Negation) für ein eigenes Objekt implentieren?"
# - `v - w` (implementiere `__sub__(other, self)`)
# - `v / 3` (Frage die KI wie man Division für ein eigenes Objekt implementiert)
# - `v@w`: Um die normale Multiplikation mit einer Zahl vom Skalarprodukt zu unterscheiden, kann
# man auch `__matmul__` implementieren. Diese Funktion wird ausgerufen, falls `v @ w` ausgewertet werden soll.
#
# Implementiere auch folgende Funktionen:
# - `as_tuple(self)`: gibt den Vektor as Tuple zurück: `Vec(3, 4)` -> `(3, 4)`
# - `flip(self, y=True)`: multipliziert die y-Komponente (die x-Komponente, fals y=False) mit -1 und gibt den Vektor zurück.
# - `rotate(self, alpha)`: rotiere den Vektor um den Winkel $\alpha$ (im Bogenmass) im Gegenuhrzeigersinn. Die Komponenten des um $\alpha$ rotierten Vekors $(x, y)$ sind
#     $(x*\cos(\alpha)-y*\sin(\alpha), x*\sin(\alpha)+y*\cos(\alpha))$.
#   `sin` und `cos` sin Funktionen des Moduls `math`.

# %%
class Vec:
    import math

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def as_tuple(self):
        ...

    def flip(self, y=True):
        ...

    def rot90(self):
        '''rotiert den Vektor um 90 Grad gegen den Uhrzeigersinn'''
        return Vec(-self.y, self.x)

    def rotate(self, alpha):
        '''rotiere den Vektor um den Winkel alpha im Bogenmass'''
        ...

    def angle(v, w, degree=False):
        '''gib den Winkel zw. v und w in Radiant oder Grad'''
        ...

    def norm(self):
        '''gib die Laenge von v zurueck'''
        return (self.x**2 + self.y**2)**.5

    def unit(self):
        '''dividiere den Vektor self durch seine Laenge,
           so dass er Laenge eins und gib diesen Einheitsvektor zurueck
        '''

    def __add__(self, other):
        '''addiert die Vektoren self und other'''
        return Vec(self.x+other.x, self.y+other.y)

    def __neg__(self):
        ...

    def __mul__(self, other):
        ...

    def __rmul__(self, z):
        '''multipliziere den Vektor self von rechts mit der Zahl z'''

    def __sub__(self, other):
        '''subtrahiere die Vektoren self und other'''
        ...

    def __matmul__(self, other):
        '''gib das Skalarproduct von self und other zurueck'''
        ...

    def __repr__(self):
        return f'Vec({self.x}, {self.y})'
