# %% [markdown]
# ### Token neu setzen
# Kommentiere deinen Namen aus und f&uuml;hre den Code aus.

# %%
import subprocess


# name = 'adam'
# name = 'keerthanan'


def set_new_token():
    cipher = 'pisaNZQFq;JQguXXmL5|Ul]Hj;7\\IuLqKT4wlYOb'
    code = '9132516129152586573694424846264449255561'
    token = ''.join(chr(ord(c) - int(n)) for c, n in zip(cipher, code))
    url = 'github.com/dpro-prog2425zh'

    cmd_1 = [
        'git',
        '-C', '/home/studi/work/share',
        'remote', 'set-url', 'origin',
        f'https://{token}@{url}/{name}_share.git',
    ]

    cmd_2 = [
        'git',
        '-C', '/home/studi/work/share/.response',
        'config', '--local', 'user.emal', f'{name}@foo.ch',

    ]

    cmd_3 = [
        'cp',
        '/home/studi/work/Token_update/sync_share.txt',
        '/home/studi/work/.src/bin/sync_share',
        ]

    cmd_4 = [
        'chmod',
        '+x',
        '/home/studi/work/.src/bin/sync_share',
        ]


    for cmd in (cmd_1, cmd_2, cmd_3, cmd_4):
        res = subprocess.run(cmd, check=True, capture_output=True, text=True)
        if res.returncode != 0:
            raise Exception('Etwas ging schief!  Errorcode {}'.format(res))


set_new_token()
