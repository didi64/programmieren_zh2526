# %% [markdown]
# ### Weitere Aufgaben zur Klasse Vector
#
# 1. Erstelle ein File `drawing_helpers.py` mit `draw_arrow` (und was dazugehört) aus
# `L31/Loesungen_Vektoren_L30.ipynb`. Verschiebe es in den Ordner `modules`.  Importiere und teste!
# 2. Spiegle den Punkt `P = (70, 30)` an der Gerade durch `A = (20, 30)` und `B = (90, 60)`.
#    - Berechne den Richtungsvektor der Gerade `AB` mit Länge 1 -> `f1`
#    - Rotiere `f1` um 90 Grad im Gegenuhrzeigersinn -> `f2`
#    - `AQ = (AP @ f1) * f1 - (AP @ f2) * f2`
#    - Reproduziere einige Elemente dieser Figur.
# <img src="/files/images/reflection.png"><br>
# 3. Schreibe eine Funktion
#
# ```python
# def reflection(A, B, P):
#     '''Spiegle den Punkt P an der Gerade durch A und B und gib ihn zurueck'''
# ```

# %%
A = (20, 30)
B = (90, 60)
P = (70, 30)


def stroke_line(canvas, v, w, color='black', line_width=1):
    canvas.save()
    canvas.stroke_style = color
    canvas.line_width = line_width
    canvas.stroke_line(*v.as_tuple(), *w.as_tuple())
    canvas.restore()

# %%
from vector import Vector as Vec
import drawing_helpers as H
import widget_helpers as W


canvas = W.get_canvas()
canvas
