# %% [markdown]
# ### Provisorischer Präsentationsplan und Zeitfenster für die mündliche Prüfung
#
# **Mündliche Prüfung zur Projektarbeit (15')**.
# Via Teamscall. Du hast dein Projekt im Jupyterlab geöffnet und teilst den Bildschirm mit mir.
# Ich werde ein paar technische Fragen zum Programmcode stellen.
# Auch werden wir zusammen deinen Code testen und kleine Modifikationen vornehmen.
#
# **Zeitfenster für die mündliche Prüfung**:
# Jeweils abends
# ```
# Di   Mi   Do   Fr
# 17.3 18.3 19.3 20.3
# 24.3 25.3 26.3 27.2
# ```
#
# von
# - 18:00-18:15
# - 18:25-18:40
# - 18:40-18:55
#
# und
# - 19:15-19:30
# - 19:40-19:55
#
# Teil mir bitte **bis Donnerstag, 12.3.** mit (Email oder Teams), welche Daten für euch in Frage kommen.
# Ev. geht auch Etwas früher oder später.
#
# **Präsentationsplan (vor Ort)**:
# **Montag, 16.3.**
# - 18:00- 18:10 Thomas (Hangman)
# - 18:10- 18:20 Rugero (4-gewinnt)
# - 18:20- 18:30 Alisir (4-gewinnt)
# - 18:30- 18:40 Adam (Minesweeper)
# - 18:40- 18:50 Patrick (Minesweeper)
#
# &nbsp;
#
# - 19:00- 19:10 Luxshan (TikTakToe)
# - 19:10- 19:20 Engjell (TikTakToe)
# - 19:20- 19:30 Meriton(TikTakToe)
# - 19:30- 19:40 Andreas (Memorize the Path)
# - 19:40- 19:50 Atilla (Memory)
#
# &nbsp;
#
# - 20:00- 20:10 Elias K. (Wordle)
# - 20:10- 20:20 Simon (Mastermind)
# - 20:20- 20:30 Nico (Battleship)
# - 20:30- 20:40 Tobias M. (Blackjack)
# - 20:40- 20:50 Elias S. (Mensch ärgere dich nicht!)
#
# **Montag, 23.3.**
# - 18:00- 18:10 Tobias G. (Space_Invader)
# - 18:10- 18:20 Ivan (Snake)
# - 18:20- 18:30 Keri (Pong)
# - 18:30- 18:40 Enes (Türme von Hanoi)
