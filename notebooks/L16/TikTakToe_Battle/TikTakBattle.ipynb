# %%
import tiktak_battle as B
from tiktakviewer import GameViewer

# %%
wins, losses = B.battle(None, B.wta_strategy)
wins, losses
# Out:
# ([(7, 4, 0, 2, 6, 3, 8),
#   (8, 4, 0, 2, 6, 3, 7),
#   (8, 4, 0, 2, 6, 3, 7),
#   (6, 4, 5, 0, 8, 2, 7),
#   (7, 4, 0, 2, 6, 3, 8),
#   (5, 4, 7, 0, 8, 2, 6)],
#  [])

# %%
gv = GameViewer(wins)
gv
# Out:
# HBox(children=(MultiCanvas(height=190, layout=Layout(border_bottom='1px solid black', border_left='1px solid b…
