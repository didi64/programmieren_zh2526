# %% [markdown]
# ### Hangman

# %%
import hangman

# %%
hangman.new_game()
# Out:
# Event: new_game, kwargs: {'secret': 'STERNE'}

# %%
hangman.guess('S')
# Out:
# Event: correct_guess, kwargs: {'letter': 'S'}

# %%
hangman.guess('X')
# Out:
# Event: wrong_guess, kwargs: {'f_count': 1}

# %%
import hangman
# from hangman_class import Hangman
from ipycanvas import Canvas
from ipywidgets import Output, Button
from IPython.display import display

# hangman = Hangman()

layout = {'border': '1px solid black'}
out = Output(layout=layout)
canvas = Canvas(width=200, height=100, layout=layout)
button = Button(description='New Game')


def update_view(event, **kwargs):
    canvas.clear()
    canvas.fill_text(f'{event}, {kwargs}', 10, 30)


@out.capture(clear_output=True)
def on_key_down(key, *flags):
    print(key)
    hangman.guess(key.upper())


hangman.update = update_view
canvas.on_key_down(on_key_down)
button.on_click(lambda bt: hangman.new_game())

display(canvas, button, out)
# Out:
# Canvas(height=100, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right=…
# Button(description='New Game', style=ButtonStyle())
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
hangman.state
# Out:
# {'f_count': 6,
#  'secret_word': 'BILDSCHIRM',
#  'letters_to_guess': {'B', 'C', 'D', 'H', 'I', 'L', 'M', 'R', 'S'},
#  'guessed_letters': ''}
