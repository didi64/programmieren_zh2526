# %% [markdown]
# ### Prüfung vom 19. Januar 2026
#
# **Allgemeines**
# - Zeit: 90 Minuten.
# - Hilfsmittel: Unterrichtunterlagen, Notizen, ...
# - **Vorboten** ist die Kommunikation mit anderen Personen in jeglicher Form, AI, Chat-GPT, ...
#
# **Vorbereitung**
# - Verschiebe den  Ordner `Pruefung_2026` in deinen share-Ordner.
#
# **Allgemeine Hinweise**
# - Führe jeweils die Codezelle nach der Aufgabestellung aus, um die in der Aufgabenstellung erwähnten Module und Variablen zu importieren bez. zu definieren.
# - Bei manchen Aufgaben ist einer Variable etwas zuzuweisen.
#   Oft ist dieser Wert der gleichnamigen Variable im Modul `loesungen`
#   zugewiesen.
# - Bei manchen Aufgaben ist eine Funktion zu programmieren, die später verwendet wird.
# Falls deine Funktion nicht wie gewünscht funktioniert, kannst du
# statt dessen die gleichnamige Funktion aus dem Modul `loesungen` verwenden.
# - Im Modul `loesungen` definierte Variabeln sind in der ersten Codezelle als Kommentar aufgeführt.
#
# **Abgabe**
# - Stelle sicher, dass die letzten Änderungen gespeichert sind (drücke Ctrl-s).
# - Führe im Jupyterlab-Terminal den Befehl `sync_share` aus.
# Falls das nicht klappen sollte, dann schicke die Notebooks mit deinen Lösungen per Email an `dieter.probst@edu.teko.ch`.
#
#
# **Viel Erfolg!**

# %%
import loesungen

# loesungen.numbers
# loesungen.cubes
loesungen.get_sum([1, 2, 3])
