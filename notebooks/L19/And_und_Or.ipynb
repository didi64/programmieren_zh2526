# %% [markdown]
# ### Question
#
# Frage: Was macht die Funktion f? W
#
# def f(x):
#     return (x > 0) - (x < 0)
#
# # Alle Faelle
# [True - False,  # x > 0
#  False - False,  # x == 0
#  False - True,  # x < 0
#  ]
#
# Was macht `and` und `or` mit beliebigen Objekten?
#
# x and y gibt
# - x zurueck, falls bool(x) False ist
# - gibt y zurueck, falls bool(x) True ist
#
# x and y gibt
# - x zurueck, falls bool(x) True ist
# - gibt y zurueck, falls bool(x) False ist

# %%
[] and 'foo'
# Out:
# []

# %%
[] or 'foo'
# Out:
# 'foo'

# %%
'bar' and 'foo'
# Out:
# 'foo'

# %%
'bar' or 'foo'
# Out:
# 'bar'

# %%
x = True or print('test')
print(x)
# Out:
# True

# %%
x = True and print('test')
print(x)
# Out:
# test
# None

# %%
x = False or print('test')
print(x)
# Out:
# test
# None

# %%
x = False and print('test')
print(x)
# Out:
# False
