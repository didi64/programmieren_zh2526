# %% [markdown]
# ### Module (Nachtrag)
# Suche mit dem Notebookfinder im Ordner `_src` nach `modul`, um
# den alten Stoff zu Module zu repetieren.
#
# **Neu** sind folgende Ergänzungen:
# - DocString für ein Modul: Ist der erste Ausdruck in einem Modul `foo.py` ein DocString der Form
#   ```python
#   '''
#   Dies ist ein DocString fuer ein Modul
#   '''
#   ```
#   wird dieser angezeigt, wenn **nach erfolgtem Import**
#   ```python
#   help(foo)
#   ```
#   ausgeführt wird.
#   Diese Funktion gibt zudem alle im Modul definierten Funktionen in alphabetischer Reihnefolge mit Signatur und DocString aus, ebenso die im Module definierten Variabeln.
# - Tests zu einem Modul hinzufügen, bez. das Pattern
#   ```python
#   if __name__ == '__main__':
#       # do stuff (z.B. teste Funktionen dieses Moduls)
#   ```
#   &nbsp;
#   Wird ein Modul `foo.py` importiert, wird der (globalen) Variable `__name__` dieses Moduls der String `'foo'` zugewiesen.
#   Wird das Modul dagegen mit der Zeilen-Magic `%run -m foo` ausgeführt, so wird
#   `__name__` der String `'__main__'` zugewiesen.
#   Das erlaubt zu testen, ob das Modul importiert oder aus geführt wird.

# %%
# %run -m nbf

# %%
# %%file foo.py
print(f'__name__: "{__name__}"')
# Out:
# Overwriting foo.py

# %%
# %run -m foo
# Out:
# __name__: "__main__"

# %%
import foo
# Out:
# __name__: "foo"

# %%
foo.__name__
# Out:
# 'foo'

# %% [markdown]
# **Aufgaben I**:
# - Verschiebe die Module `widget_helpers` und `grid_helpers` in den Ordner `modules`.
# - Importiere die Module und gib mit `help(<Modulname>)` den Hilfstext aus.
# - Führe die Module aus, statt sie zu importieren.

# %% [markdown]
# **Aufgaben II**:
# Nutze die Module  `widget_helpers` und `grid_helpers`.
# 1. Erstelle eine MultiCanvas mit 2 Layern, bg und fg.
#    Zeichne ein GItter mit 4 Spalten und 3 Reihen mittig auf den Vordergrund fg.
# 2. Implementiere und teste folgende Funktion:
# ```python
# def fill_triangle(canvas, pos, grid_spec, anchor=0, color='black'):
#     '''verbinde 3 Ecken des Gitterfeldes pos=(col, row) zu einem Dreieck.
#        Der rechte Winkel ist bei der Ecke anchor
#        (die linke obere Ecke ist Ecke 0, aufgezaehlt wir im Gegenuhrzeigersinn).
#     '''
#     ...
# ```
# 3. Erstelle mit Hilfe der Funktion `fill_triangle` folgende Zeichnungen:<br>
#    <img src='/files/images/L19_diamond.png'> <img src='/files/images/L19_diagonal.png'>
