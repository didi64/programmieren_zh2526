# %%
class InstanceDict(dict):
    def __getitem__(self, key):
        if key in self:
            return super().__getitem__(key)

        elif key in self['__class__']:
            attr = self['__class__'][key]
            if not callable(attr):
                return attr
            else:
                return lambda *args, **kwargs: attr(self, *args, **kwargs)

        else:
            raise AttributeError(f'Attribute {key} not found!')

# %%
class ClassDict(dict):
    def __call__(self, *args, **kwargs):
        d = InstanceDict({'__class__': self})

        __init__ = self.get('__init__')
        if __init__:
            __init__(d, *args, **kwargs)

        return d

    def __repr__(self):
        return f'Class {id(self)}'

# %%
Person = ClassDict()
Person
# Out:
# Class 140108882735056

# %%
def __init__(self, name, age):
    self['name'] = name
    self['age'] = age


def birthday(self):
    self['age'] += 1


def show(self):
    print(f'Person(name={self['name']}, age={self['age']}')

# %%
Person['__init__'] = __init__
Person['birthday'] = birthday

# %%
Person
# Out:
# Class 140108882735056

# %%
Person['birthday']
# Out:
# <function __main__.birthday(self)>

# %%
bob = Person('Bob', 20)

# %%
bob['age']
# Out:
# 20

# %%
bob
# Out:
# {'__class__': Class 140108882735056, 'name': 'Bob', 'age': 20}

# %%
bob['birthday']()
bob
# Out:
# {'__class__': Class 140108882735056, 'name': 'Bob', 'age': 21}
