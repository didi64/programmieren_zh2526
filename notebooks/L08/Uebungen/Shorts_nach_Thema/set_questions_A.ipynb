# %% [markdown]
# ### Kleine Aufgaben zum Typ `set`
# **Warm-up**:
# Erstelle eine leere Menge `numbers`.
# 1. Füge die Zahlen 1, 2 und 3 zur Menge hinzu.
# 2. Entferne das Element 1 aus der Menge.
# 1. Entferne irgend ein Element aus der Menge (mit `pop`)
# 1. Erstelle zwei Mengen mit Zahlen. Bilde den Durchschnitt, die Vereinigung und die Differenz dieser Mengen.
#    Benutze die Operatorn `&`, `|`  und `-`.
#
# **Eigentliche Aufgaben**:
# Implementiere die Funktionen in den nachstehenen Codezellen.
# Programmiere die Funktion zuerst ohne String-Methoden, List-Comprehension, zip und enumerate zu nutzen.
# Falls sinnvoll, implementiere eine kompaktere Version ohne diese Einschränkungen.
#
# Der Doc-String beschreibt, was die Funktion tun soll.
# Bei korrekter Implementation ist der Ausdruck in der
# nächsten Zelle jeweils `True`.
#
# **Hint** zu Funktion `alphabet`: `chr(65)` ist `'A'`, `chr(66)` ist `'B'`, ...

# %%
numbers = set()
numbers

# %%
numbers.add(1)
numbers.add(2)
numbers.add(3)
numbers

# %%
numbers.remove(1)
numbers

# %%
numbers.pop()
numbers

# %%
xs = {1, 2, 3}
ys = {2, 3, 5}
xs & ys, xs & ys, xs - ys

# %%
def set_intersection(xs, ys):
    '''gib  eine Menge mit den Elementen, die in  xs UND ys sind zurueck'''
    return set(x for x in xs if x in ys)

# %%
xs = {1, 2, 3}
ys = {2, 3, 5}
set_intersection(xs, ys) == xs & ys

# %%
def set_diff(xs, ys):
    '''gib eine Menge mit den Elemente, die in xs aber nicht in ys sind zurueck'''
    return set(x for x in xs if x not in ys)

# %%
xs = {1, 2, 3}
ys = {2, 3, 5}
set_diff(xs, ys) == xs - ys

# %%
def set_union(xs, ys):
    '''gib  eine Menge mit den Elementen, die in  xs ODER ys sind zurueck'''
    union = set(xs)
    for y in ys:
        union.add(y)

    return union

# %%
xs = {1, 2, 3}
ys = {2, 3, 5}
set_union(xs, ys) == xs | ys

# %%
def unique(xs):
    '''gib eine Liste zurueck, die jedes Element von xs
       in der gleichen Reihenfolge enthalt, aber nur einmal.
       xs: list
    '''
    unique = []
    seen = set()
    for x in xs:
        if x not in seen:
            unique.append(x)
            seen.add(x)
    return unique

# %%
unique([1, 4, 3, 2, 1, 2, 1]) == [1, 4, 3, 2]
