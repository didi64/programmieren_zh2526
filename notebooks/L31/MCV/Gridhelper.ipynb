# %% [markdown]
# ### Gridhelper
# Gridhelper ist nun eine Klasse, erledigt aber im wesentlichen die
# gleichen Aufgaben wir das Module `gird_helpers`.

# %%
# %run gridhelper.py

# %%
s = set()
s.discard(1)

# %%
from gridhelper import GridHelper


width, height = 200, 100
ncol, nrow = 8, 5

dx = width/(ncol + 2)  # total ncol+2 Spalten mit Breite dx
dy = height/(nrow + 2)

grid_spec = [dx, dy, dx, dy, ncol, nrow]
gridhelper = GridHelper(*grid_spec)
gridhelper

# %%
import widget_helpers as W
mcanvas = W.get_mcanvas(2, width, height)
bg, fg = mcanvas
mcanvas

# %%
mcanvas.clear()
gridhelper.draw_grid(fg, line_width=2, color='blue')
gridhelper.fill_circle(bg, (2, 4), color='red')
