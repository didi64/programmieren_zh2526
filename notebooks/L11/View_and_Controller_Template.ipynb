# %% [markdown]
# ### View und Controller (Template)

# %%
import game

game.new_game()
# Out:
# event: new_game, data: [5, 4, 3, 2, 1]

# %%
game.swap()
# Out:
# event: swap, data: [4, 5, 1, 2, 3]

# %%
game.rotate()
# Out:
# event: rotate, data: [4, 3, 5, 1, 2]

# %%
from IPython.display import display
from ipycanvas import MultiCanvas
from ipywidgets import Output


layout = {'border': '1px solid black'}
out = Output(layout=layout)

# %%
@out.capture(clear_output=True)
def on_key_down(key, *flags):
    print(f'key pressed: {key}')
    if key == 'ArrowUp':
        game.swap()
    if key == 'ArrowRight':
        game.rotate()
    if key == 'n':
        game.new_game()

# %%
@out.capture()
def update(event, data):
    print(f'event: {event}, data: {data}')


game.update = update

# %%
def draw_bg():
    pass

# %%
mcanvas = MultiCanvas(2, width=200, height=200, layout=layout)
bg, fg = mcanvas

draw_bg()
mcanvas.on_key_down(on_key_down)

display(mcanvas, out)
# Out:
# MultiCanvas(height=200, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_r…
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
out.clear_output()

# %%
game.new_game()

# %%
game.swap()

# %%
game.rotate()
