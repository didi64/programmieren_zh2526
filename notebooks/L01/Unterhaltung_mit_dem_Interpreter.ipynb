# %% [markdown]
# ### Unterhaltung mit dem Python-Interpreter
#
# Es gibt kompilierte und interpretierte Sprachen.
#
# **[Kompilierte Sprachen](https://en.wikipedia.org/wiki/Compiled_language)**:
# Ein Programm ist im wesentlichen eine Folge von Symbolen, sagen wir ein Text, der nach bestimmten Regeln geformt ist.
# Ein &Uuml;bersetzungsprogramm, der Kompiler, produziert aus diesem Text eine Folge von Nullen und Einsen,
# ein **Binary** (bin&auml;res File), welches Anweisungen enth&auml;lt, die direkt vom Prozessor/Betriebssystem ausgef&uuml;hrt werden k&ouml;nnen.
#
# Beispiele: C, C++.
#
# **[Interpretierte Sprachen](https://en.wikipedia.org/wiki/Interpreter_(computing))**:
# Hier wird der Programmcode nicht in ein Binary &uuml;bersetzt.
# Stattdessen f&uuml;hrt der Interpreter (auch ein Programm) Anweisung um Anweisung des Programmcodes aus.
#
# Beipiele: Python, JavaScript.
#
# **Kompilierte Programme** sind **schneller** als interpretierter Code.
# Das kompilierte Programm ist optimiert auf eine bestimmte Prozessorarchitektur und Betriebssystem.
# **Interpretierte Sprachen** sind daf&uuml;r **plattformunabh&auml;ngig**, da der Interpreter die Anweisungen des Programms selber ausf&uuml;hrt.

# %% [markdown]
# ### Python-Interpreter in Jupyterlab-Terminal starten
#
# Klicke auf <span style="background-color:blue; color:white">&nbsp;&nbsp;+&nbsp;&nbsp;</span>  und dann unter *Other* auf Terminal. Tippe dann im Terminal den Befehl $\texttt{python}$, um den Interpreter im interaktiven Modus zu starten, dem sog. Read-Evaluate-Print Loop (REPL).
# ```
# studi@jlab $ python
# Python 3.13.0 (main, Dec  8 2024, 01:54:23) [GCC 9.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# ```
#
# Nach dem Prompt `>>>` kann man nun Python Code eingeben und ausf&uuml;hren lassen, z.B.
# `print('test')`.
#
# Er liest und evaluiert die Eingabe und produziert entsprechenden Output.
# Versteht der Interpreter die Anweisung nicht oder kann er diese nicht ausf&uuml;hren, wird eine Fehlermeldung angezeigt.
# Der REPL kann mit **ctr-d**  oder dem Befehl **exit** verlassen werden.
# Mit ↑ und ↓ kann durch die Eingabehistory gebl&auml;ttert werden.
#
#
# Um den Python interpreter ein Python-Programm ausf&uuml;hren zu lassen, tippt man
# im Terminal `python <Pythonfile>`, z.B.
# ```
# studi@jlab $ python hello.py
# ```

# %% [markdown]
# ### Jupyterlab
# Jupyterlab erleichter die Unterhaltung mit dem Interpreter.
# Python Code wir einfach in eine Code-Zelle geschrieben und bei Bedarf
# durch Dr&uuml;cken von **shift-Enter** oder **Ctrl-Enter** in dieser Zelle an den
# Interpreter weitergereicht. Der Antwort des Interpreters wird dann in geeigneter Form im Notebook dargestellt.
# **Kommentare**: Text nach einem `#` bis ans Ende der Zeile ist ein Kommentar und wird vom Interpreter ignoriert.

# %%
2 + 2  # addiere 2 und 2
# Out:
# 4

# %%
# hello word
print('hello, world!')
# Out:
# hello, world!
