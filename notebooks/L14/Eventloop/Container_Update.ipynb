# %% [markdown]
# ### Container-Update
# - Führe im Windows Command Prompt Folgendes aus:
# > docker pull dieterprobst/jlab:3.1
#
# - In Docker Destkop, klicke rechts auf Images. Starte das Image
# *dieterprobst/jlab:3.1*.
# Expandiere *Optional Settings* und gib bei
# *Local Host*, *Host Path* und *Container Path*
#   Folgendes an:
#
# ```
# Local Host: 10000
#
# Host Path: selektiere deinen Ordner programmiern
#
# Container Path: /home/studi/work
# ```
