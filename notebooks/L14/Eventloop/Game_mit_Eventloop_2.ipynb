# %% [markdown]
# ### Game mit Eventloop
# mention reimport
# problem mit mehrfach registrierung von des
# on)mouse_down callbacks bei wiederholtem ausfuehren

# %%
import darstellung as D
from IPython.display import display


display(D.canvas, D.out)
# Out:
# Canvas(height=100, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right=…
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
size = (19, 19)
D.new_game(head=(9, 9), size=size)

# %%
heads = [(10, 9), (10, 10), (9, 10), (9, 9)] 
for head in heads:
    D.move(head, size)

# %%
D.game_over()

# %% [markdown]
# ***
# Starte den Kernel um erneutes Importieren zu erzwingen.
# Damit neue Canvas un nicht alte, ebenso out
# ***

# %%
import game
import darstellung as D
from IPython.display import display

# um nicht immer D.out und D.canvas tippen zu muessen
out = D.out
canvas = D.canvas

key_move = {'ArrowUp': (0, -1),
            'ArrowDown': (0, 1),
            'ArrowLeft': (-1, 0),
            'ArrowRight': (1, 0),
            }


@out.capture(clear_output=True)
def on_key_down(key, *flags):
    print(key)
    if key.startswith('Arrow'):
        dx, dy = key_move[key]
        game.move(dx, dy)
    if key == 'n':
        game.new_game()


def update(event, **kwargs):
    # print(event, kwargs)
    if event == 'new_game':
        D.new_game(**kwargs)
    if event == 'game_over':
        D.game_over()
    if event == 'move':
        D.move(**kwargs)


game.update = update
canvas.on_key_down(on_key_down)
display(canvas, out)
canvas.focus()
# Out:
# Canvas(height=100, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right=…
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %% [markdown]
# ### Aufgabe
# add eventloop
#
# importiere event_loop, stop_event, event_queue aus eventloop.py
#
#
# in on_key_down
# move key into event_queue instead of calling move
#
# update muss sich nun nicht nur um die darstellung, sonder auch noch um
# den Eventloop kuemmern
# starte eventloop und
# stop_event.clear()
# stop_event.set()
