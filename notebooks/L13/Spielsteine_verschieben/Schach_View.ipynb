# %%
import schach

# %%
schach.new_game()
# Out:
# event: new_game, kwargs: {'pieces': [('t', 0, 0), ('s', 1, 0), ('l', 2, 0), ('d', 3, 0), ('k', 4, 0), ('l', 5, 0), ('s', 6, 0), ('t', 7, 0), ('b', 0, 1), ('b', 1, 1), ('b', 2, 1), ('b', 3, 1), ('b', 4, 1), ('b', 5, 1), ('b', 6, 1), ('b', 7, 1), ('B', 0, 6), ('B', 1, 6), ('B', 2, 6), ('B', 3, 6), ('B', 4, 6), ('B', 5, 6), ('B', 6, 6), ('B', 7, 6), ('T', 0, 7), ('S', 1, 7), ('L', 2, 7), ('D', 3, 7), ('K', 4, 7), ('L', 5, 7), ('S', 6, 7), ('T', 7, 7)], 'ptm': 0}

# %%
schach.move('e2', 'e4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 schach.move('e2', 'e4')
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:63, in move(src, target)
#      62 def move(src, target):
# ---> 63     if not is_legal(src, target):
#      64         return
#      65     char = get_field(*src)
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:53, in is_legal(src, target)
#      47 def is_legal(src, target):
#      48     '''Zug ist legal, falls
#      49        - Figur auf Startfeld
#      50        - Spieler am Zug (Figursymbol ist klein fuer SPieler 1)
#      51        - keine eigene Figur wird geschlagen
#      52     '''
# ---> 53     char_0 = get_field(*src)
#      54     char_1 = get_field(*target)
#      55     if char_0 == SPACE:
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:30, in get_field(col, row)
#      29 def get_field(col, row):
# ---> 30     return board[row][col]
#
# TypeError: list indices must be integers or slices, not str

# %%
schach.board
# Out:
# [['t', 's', 'l', 'd', 'k', 'l', 's', 't'],
#  ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b'],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
#  ['T', 'S', 'L', 'D', 'K', 'L', 'S', 'T']]

# %%
import helpers as H


BOARD_SPEC = (20, 20, 20, 20, 8, 8)


def draw_chessboard(canvas):
    H.draw_board(canvas, BOARD_SPEC)


def place_pieces(canvas, pps):
    x0, y0, dx, dy, ncol, nrow = BOARD_SPEC
    canvas.font = f'{dx}px sans-serif'
    canvas.text_align = 'center'
    canvas.text_baseline = 'ideographic'
    for piece, col, row in pps:
        canvas.clear_rect(x0+col*dx, y0+row*dy, dx, dy)
        canvas.fill_text(piece, x0+(col+0.5)*dx, y0+(row+1)*dy)


def update(canvas, event, data):
    if event == 'new_game':
        canvas.clear()
        place_pieces(canvas, data)
    if event == 'move':
        place_pieces(canvas, data)

# %%
from ipycanvas import MultiCanvas


layout = {'border': '1px solid black'}
mcanvas = MultiCanvas(2, width=200, height=200, layout=layout)
bg, fg = mcanvas

draw_chessboard(bg)
pieces = schach.get_pieces()
place_pieces(fg, pieces)

mcanvas
# Out:
# MultiCanvas(height=200, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_r…

# %%
schach.new_game()
update(fg, 'new_game', schach.get_pieces())
# Out:
# event: new_game, kwargs: {'pieces': [('t', 0, 0), ('s', 1, 0), ('l', 2, 0), ('d', 3, 0), ('k', 4, 0), ('l', 5, 0), ('s', 6, 0), ('t', 7, 0), ('b', 0, 1), ('b', 1, 1), ('b', 2, 1), ('b', 3, 1), ('b', 4, 1), ('b', 5, 1), ('b', 6, 1), ('b', 7, 1), ('B', 0, 6), ('B', 1, 6), ('B', 2, 6), ('B', 3, 6), ('B', 4, 6), ('B', 5, 6), ('B', 6, 6), ('B', 7, 6), ('T', 0, 7), ('S', 1, 7), ('L', 2, 7), ('D', 3, 7), ('K', 4, 7), ('L', 5, 7), ('S', 6, 7), ('T', 7, 7)], 'ptm': 0}

# %%
schach.move('e2', 'e4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 schach.move('e2', 'e4')
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:63, in move(src, target)
#      62 def move(src, target):
# ---> 63     if not is_legal(src, target):
#      64         return
#      65     char = get_field(*src)
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:53, in is_legal(src, target)
#      47 def is_legal(src, target):
#      48     '''Zug ist legal, falls
#      49        - Figur auf Startfeld
#      50        - Spieler am Zug (Figursymbol ist klein fuer SPieler 1)
#      51        - keine eigene Figur wird geschlagen
#      52     '''
# ---> 53     char_0 = get_field(*src)
#      54     char_1 = get_field(*target)
#      55     if char_0 == SPACE:
#
# File ~/Projects/JupyterNotebooks/programmieren_zh2526/notebooks/L13/Spielsteine_verschieben/schach.py:30, in get_field(col, row)
#      29 def get_field(col, row):
# ---> 30     return board[row][col]
#
# TypeError: list indices must be integers or slices, not str

# %%
data = ((' ', 4, 6), ('B', 4, 4))
update(fg, 'move', data)
