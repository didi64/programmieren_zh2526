# %%
import schach_1 as schach

# %%
schach.board
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
schach.new_game()
schach.board
# Out:
# event: new_game, kwargs: {'changes': [('t', 0, 0), ('s', 1, 0), ('l', 2, 0), ('d', 3, 0), ('k', 4, 0), ('l', 5, 0), ('s', 6, 0), ('t', 7, 0), ('b', 0, 1), ('b', 1, 1), ('b', 2, 1), ('b', 3, 1), ('b', 4, 1), ('b', 5, 1), ('b', 6, 1), ('b', 7, 1), ('B', 0, 6), ('B', 1, 6), ('B', 2, 6), ('B', 3, 6), ('B', 4, 6), ('B', 5, 6), ('B', 6, 6), ('B', 7, 6), ('T', 0, 7), ('S', 1, 7), ('L', 2, 7), ('D', 3, 7), ('K', 4, 7), ('L', 5, 7), ('S', 6, 7), ('T', 7, 7)]}
# [['t', 's', 'l', 'd', 'k', 'l', 's', 't'],
#  ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b'],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'],
#  ['T', 'S', 'L', 'D', 'K', 'L', 'S', 'T']]

# %%
schach.raw_move((3, 6), (3, 4))
schach.board
# Out:
# event: move, kwargs: {'changes': ((' ', 3, 6), ('B', 3, 4))}
# [['t', 's', 'l', 'd', 'k', 'l', 's', 't'],
#  ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b'],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'B', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  ['B', 'B', 'B', ' ', 'B', 'B', 'B', 'B'],
#  ['T', 'S', 'L', 'D', 'K', 'L', 'S', 'T']]
