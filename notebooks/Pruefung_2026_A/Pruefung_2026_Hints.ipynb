# %% [markdown]
# ### Themen und Lösungshinweisen zu den einzelnen Aufgaben
# Umfang: L08/Cheatsheet.ipynb
#
# - Aufgabe 1: Listcomprehension, range, For-Schleifen
#   L06/For_Schleifen_I.ipynb
#   L07/Listcomprehension.ipynb
#
# - Aufgabe 2: Slicenotation
#   L04/Indexing_und_Slicing_I.ipynb
#
#
# - Aufgabe 3: Sortieren
#   L08/Sortieren_mit_Lambdaausdruecken.ipynb
#   L08/Dicts.ipynb
#   L09/Loesungen_09/Sortieren_A.ipynb
#
#
# - Aufgabe 4: Files, ie Stringmethoden strip, split und join
#   L07/Files.ipynb
#   L06/Stringmethoden.ipynb
#
# - Aufgabe 5: Zufallsexperiment, Count-Dict
#   L08/Anwendungen_Dict_I.ipynb
