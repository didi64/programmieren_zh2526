# %%
minus = 'l12;sblue;g100,100;dg200,100;'
T = minus + 'uG-50,0;dG0,75;'
div_sign = minus + 'fblue;ug150,125;C10;g150,75;C10;'

# %%
colors = ['red', 'blue', 'yellow', 'teal', 'orange', 'pink']
size = 25
cmds = [f'f{color};R{size},{size};G{size},0;' for color in colors]
draw_rects = ''.join(cmds)

# %%
draw_rects
# Out:
# 'fred;R25,25;G25,0;fblue;R25,25;G25,0;fyellow;R25,25;G25,0;fteal;R25,25;G25,0;forange;R25,25;G25,0;fpink;R25,25;G25,0;'

# %%
import zeichnungsautomat as ZA
WIDTH = 300
HEIGHT = 200
automat, canvas = ZA.get_automat_and_canvas(width=WIDTH, height=HEIGHT)
canvas
# Out:
# Canvas(height=200, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right=…

# %%
canvas.clear()
canvas.reset()
automat.read(T)

# %%
canvas.clear()
canvas.reset()
automat.read(div_sign)

# %%
canvas.clear()
canvas.reset()
automat.read(draw_rects)
