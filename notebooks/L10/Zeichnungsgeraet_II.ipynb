# %% [markdown]
# ### Zeichnungsgerät 2
#
# Wir benutzen wieder den im Notebook [Automaten](Automaten.ipynb) beschriebenen Automat um einen Zeichnungsgerät zu steuern.
#
# Wir schreiben Python-Code, der Zeichungsanweisungen für unser Zeichnungsgerät generiert.

# %%
grid_config = {
    'position': (40, 10),
    'width': 210,
    'height': 180,
    'ncol': 7,
    'nrow': 6,
    'linewidth': 2,
    'linecolor': 'blue',
}

# %%
def make_grid_cmd(position, width, height, ncol, nrow, linewidth, linecolor):
    cmds = []
    x0, y0 = position
    dx, dy = width/ncol, height/nrow

    cmds.append(f'l{linewidth};')
    cmds.append(f's{linecolor};')

    # zeichen horizontale Gitterlinien
    for i in range(nrow+1):
        cmds.append('u')
        cmds.append(f'g{x0},{y0 + i*dy};')
        cmds.append('d')
        cmds.append(f'G{width},{0};')

    # zeichen vertikale Gitterlinien
    for i in range(ncol+1):
        cmds.append('u')
        cmds.append(f'g{x0 + i*dx},{y0};')
        cmds.append('d')
        cmds.append(f'G{0},{height};')

    return ''.join(cmds)

# %%
make_grid_cmd(**grid_config)

# %%
def make_place_cmd(col, row, color, position, width, height, ncol, nrow, linewidth, linecolor):
    cmds = []
    x0, y0 = position
    dx, dy = width/ncol, height/nrow
    radius = min(dx-linewidth, dy-linewidth)/2 - 2

    cmds.append(f'f{color};')
    cmds.append('u')
    cmds.append('g{},{};'.format(x0, y0))
    cmds.append('G{},{};'.format((col+0.5)*dx,  (row+0.5)*dy))
    cmds.append('d')
    cmds.append('C{};'.format(radius))

    return ''.join(cmds)

# %%
make_place_cmd(1, 2, 'black', **grid_config)

# %%
def make_clear_cmd(col, row, position, width, height, ncol, nrow, linewidth, linecolor):
    cmds = []
    x0, y0 = position
    dx, dy = width/ncol, height/nrow

    cmds.append('u')
    cmds.append(f'g{x0},{y0};')
    cmds.append(f'G{col*dx},{row*dy};')
    cmds.append(f'G{linewidth/2},{linewidth/2};')
    cmds.append('e{},{};'.format(dx-linewidth-1, dy-linewidth-1))

    return ''.join(cmds)

# %%
make_clear_cmd(1, 2, **grid_config)

# %%
import zeichnungsautomat as ZA


automat, drawingBoard = ZA.get_automat_and_canvas(width=300, height=200)
drawingBoard

# %%
drawingBoard.clear()
drawingBoard.reset()
automat.read(make_grid_cmd(**grid_config))

# %%
automat.read(make_place_cmd(1, 2, 'green', **grid_config))

# %%
automat.read(make_clear_cmd(1, 2, **grid_config))
