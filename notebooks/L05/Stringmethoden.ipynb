# %% [markdown]
# ### Strings als Objekte vom Typ str
#
# In Python sind Integers, Strings, Tuple genaugenommen Objekte von Type `int`, `str` bez. `tuple`.
# Jedes Objekt `x` hat einen bestimmten Typ, welcher sich mit `type(x)` bestimmen l&auml;sst.
# Jeder Typ stellt Funktionen zur Verf&uuml;gung, mit welchen sich die Objekte
# dieses Typs manipulieren lassen.
# Exemplarisch betrachten wir hier einige Funktionen des Typs `str` (String).
# Auf die Funktionen eines Typs kann mit der **dot-Notation** zugegriffen werden.
# - `str.upper('foo')` gibt den String `FOO` zur&uuml;ck.
#   Python erlaubt, diese Funktion bequemer mit der Syntax
#   `'foo'.upper()` anzuwenden.
#   Man kann `'foo'.upper()` als Kurzform f&uuml;r
#  `str.upper('foo')` ansehen.
#  Im Falle von `'foo'.upper()` nennt man
#  `upper` auch eine Methode des Stringobjekts `'foo'`.
#
# - Tippe `str.` und dann `tab` in einer Codezelle, um die Methoden von `str` anzuzeigen.
#
# - Der Typ `str` definiert auch die Operationen
#
#   ```python
#   len('foo')
#   'foo' + 'bar'
#   'foo' * 3
#
#   ```
#
#
#   Das ist bequeme Pythons-Syntax (Syntactic sugar) f&uuml;r
#
#
#    ```python
#    str.__len__('foo')
#    str.__add__('foo', 'foo')
#    str.__mul__('foo', 3)
#
#    ```
#
#    Weiter sind
#
#
#   `'foo'[0]` ist syntactic sugar f&uuml;r `str.__getitem__(1)`
#   `'foo'[1:3]` ist syntactic sugar f&uuml;r `str.__getitem__(slice(1,3))`
#
# - **Methodchaining**: Die Methode `str.upper` gibt ein Objekt vom Typ `str` zur&uuml;ck, auf das mit der **dot**-Notation direkt eine weitere Methode angewendet werden kann z.B.
#
#   ```python
#   'foo'.upper().center(10)
#   ```

# %%
'foo'.upper().center(10)

# %%
str.center(str.upper('foo'), 10)

# %%
str.__getitem__('foo', slice(1, 3))
# Out:
# 'oo'

# %% [markdown]
# ### 25 Stringmethoden
# - W&auml;hle eine Methode und mache 2 Beispiele, die illustrieren was die Methode tut.
#   Frage ggf. Chat-GPT.
# - In welcher  Situation ist diese Methode n&uuml;tzlich?
# ```
# capitalize
# center
# count
# expandtabs
# isalnum
# isalpha
# isdigit
# isidentifier
# islower
# isnumeric
# isprintable
# isspace
# isupper
# ljust
# lower
# lstrip
# removeprefix
# removesuffix
# replace
# rstrip
# split
# splitlines
# startswith
# strip
# swapcase
# upper
# zfill
# ```

# %% [markdown]
# ### Nachtrag
# Der Begriff Typ (type) wird aus historischen Gr&uuml;nden verwendet.
# Heute ist jeder der Basistypen von Python als Klasse implementiert.

# %%
print(type(str))
