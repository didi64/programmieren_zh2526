# %% [markdown]
# ### Recap Lektion 3
# - Tuples: Ein Datentyp zum Speichern verschiedener Werte.
#   Ist `items` ein Tuple, so kann man wie bei Strings mit `items[0]`
#   ein Elemente herausgreifen und mit `len(items)` die L&auml;nge erfragen.
#   Tupel kann man mit `+` zusammenh&auml;ngen, mit `*` vervielfachen und
#   mit `==` und `<`, `<=`, ... vergleichen.
#   ```python
#   ()  # leeres Tuple
#   (1,) # einelenemtige Tuple
#   ('Max', 'Muster', 2004)  # 3-elementiges Tuple
#   ```
# - f-Strings: ein String mit Platzhaltern der Form `{<Ausdruck>}`.
#   Der Ausdruck `<Ausdruck>` wird ausgewertet, in einen String umgewandelt und an die Stelle von `{<Ausdruck>}` gesetzt.
#     ```python
#     x = 2
#     y = 3
#     f'Die Summe von {x} und {y} ist {x+y}.'
#     ```
# - Triple-quoted-Strings.
#   ```python
#   '''\
#   1. Zeile
#   2. Zeile\
#   '''
#   Ein `\` als letztes Zeichen einer Zeile zeigt an, dass der String ohne Zeilenumbruch auf der nächsten Zeile weitergeht.
# - Funktionen:
#     ```python
#         def add(x, y):
#             '''x: int
#                y: int
#                gibt die Summe von x und y zurueck
#             '''
#             return x + y
#     ```
#     Ist die Funktion `add` in einem `.py`-File (z.B. `my_functions.py`) im Ordner `modules` definiert,
#     so kann sie nach dem Import dieses Files mit `my_functions.add(1, 2)` aufgerufen werden.

# %%
numbers = (1, 2, 3)
numbers = numbers + (99,)
len(numbers), numbers[3]  # Tupel (da Klammern optional)

# %%
characters = tuple('hallo')  # Strinig in Tuple umwandeln
characters = characters + ('!',)  # Tuple hinzufuegen
characters

# %%
items = ('Alice', 'Bob', 'Carl')
i = 0
items_reversed = ()

while i < len(items):
    items_reversed = (items[i],) + items_reversed
    i = i + 1

items_reversed

# %%
x = 2
y = 3
f'Die Summe von {x} und {y} ist {x+y}.'

# %%
s = '''\
1. Zeile
2. Zeile\
'''
print(s)

# %%
def add(x, y):
    '''x: int
       y: int
       gibt die Summe von x und y zurueck
    '''
    return x + y

# %%
add(2, 3)

# %% [markdown]
# ### Aufgabe
# Kopiere das File `my_functions.py` in den Ordner `modules`, falls du noch kein
# solches File in diesem Ordner hast.
# Andernfalls, füge die neuen Funktionen in das bestehende File ein.
# Importiere dann diese File/Modul und rufe die dort definierten Funktionen auf.
#
# Ändere eine Funktion und importiere erneut.
# Stelle sicher, dass aus  `my_functions.py` im Ordner `modules` importiert wurde und nicht aus
# `my_funktions.py` im aktuellen Arbeitsverzeichnis.
