# %%
from Mastermind_gui import MastermindGUI

prompt = "Starte Mastermind GUI..."
print(prompt)
difficulty = input("Schwierigkeitsstufe auswählen (1-3) und Enter drücken: ")
if difficulty in ["1", "2", "3"]:
    print(f"Du hast Schwierigkeit {difficulty} gewählt. Viel Spaß beim Spielen! Du hast gui.game.max_attempts Versuche")
else:
    print("Ungültige Eingabe. Bitte wählen Sie eine gültige Schwierigkeitsstufe.")
    difficulty = input("Schwierigkeitsstufe auswählen (1-3) und Enter drücken: ")
gui = MastermindGUI(int(difficulty))
