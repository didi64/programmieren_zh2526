# %%
import minesweeper
'''Um Gittergösse und Anzahl Minen einzustellen,
   setze folgende Variabeln im File `minesweeper.py`.

   GRID_SIZE = 10          # Anzahl Zeilen und Spalten des Spielfelds
   NUMBER_OF_MINES = 10    # Anzahl Minen im Spielfeld
'''

minesweeper.start_game()
