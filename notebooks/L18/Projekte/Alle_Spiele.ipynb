# %% [markdown]
# - [Minesweeper 1](Minesweeper_1/Minesweeper.ipynb)
# - [Minesweeper 2](Minesweeper_2/Minesweeper.ipynb)
# - [TikTakToe 1](TikTakToe_1/TikTakToe.ipynb)
# - [TikTakToe 2](TikTakToe_2/TikTakToe.ipynb)
# - [TikTakToe 3](TikTakToe_3/TikTakToe.ipynb)
# - [Memory](Memory/Memory.ipynb)
# - [Memorygame](Memorygame/Memorygame.ipynb)
# - [Battleship](Battleship/Battleship.ipynb)
# - [Pong](Pong/Pong.ipynb)
# - [Mensch ärgere dich nicht](Mensch/Play_Mensch.ipynb)

# %% [markdown]
# &auml;
