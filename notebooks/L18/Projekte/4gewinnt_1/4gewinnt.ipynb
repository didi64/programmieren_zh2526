# %%
import grafik as G
import controller as C
from IPython.display import display


display(*C.start_game(G.make_canvas()))
# Out:
# Label(value='Spieler 1 ist dran')
# MultiCanvas(height=600)
# Button(description='Neues Spiel', style=ButtonStyle())
