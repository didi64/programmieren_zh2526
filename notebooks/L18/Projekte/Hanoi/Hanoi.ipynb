# %%
# %run hanoi.py
# Out:
# HTML(value='<b>Spielzüge:</b> 0')
# Button(description='Restart', style=ButtonStyle())
# Canvas(height=400, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right=…
