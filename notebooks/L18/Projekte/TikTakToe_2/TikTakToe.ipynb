# %%
# %run tiktaktoe.py
# Out:
# Dropdown(description='Modus:', options=(('Spieler gegen Spieler', 'pvp'), ('Spieler gegen Computer', 'pvc')), …
# Button(description='New Game', style=ButtonStyle())
# MultiCanvas(height=300, layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_r…
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…
