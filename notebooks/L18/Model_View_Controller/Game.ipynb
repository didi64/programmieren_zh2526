# %%
class Enemy:
    enemy_width = {"squid": 24,
                   "cuttlefish": 24,
                   "crab": 33,
                   "octopus": 36,
                   }
    
    enemy_points = {"squid": 30,
                    "cuttlefish": 30,
                    "crab": 20,
                    "octopus": 10,
                    }

    def __init__(self, name, pos, img=None):
        self.img = img
        self.name = name
        self.pos = pos  # position in grid (col, row)
        self.points = self.enemy_points[name]
        self.width = self.enemy_width[name]
        self.alive = True

    def get_xy(self, enemies):
        x0, y0 = enemies.offset
        col, row = self.pos
        return x0+col*enemies.dx, y0 + enemies*dy

# %%
'''
Enemies: nrows x ncols grid with enemies
         first row is bottom row


'''



class Enemies:
    attack_chance
    dattack
    laser_speed
    dlaser_speed
    
    row_name = ('squid', 'cuttlefish', 'squid', 'crab', 'octopus')
    enemies_conf = {}
    
    def __init__(self):
        self.offset = (0, 0)
        self.dx = 40
        self.dy = 40
        self.nrows = 5
        self.ncols = 10
        self.gird = [Enemy(col, row), name=..., points=..., width=...]
        self.gird_t = list(*zip(self.gird))
        self.lowest = ...
        self.n_alive = ...
        self.widest_left = pos
        self.widest_right = pos

    def get_next_widest(left=True):  # get next widest on right or left
        ...

        

    def get_next(self, col, lowest):
        ...

    def kill(self, pos):
        col, row = pos
        self.grid[row][col].alive = False
        # use get_next to update self.lowest
        # update widest_left and widest_right

    def resolve_laser(self, player_laser):
        '''return True if laser hits and needs be turn off'''
        ...
        # get square that is this
        # if this enemy is alive, kill it and

# %%
class Cannon:  # or player, where to store lives of the player?
    def __init__(self, x, imgs=None):
        self.imgs = imgs
        self.x = x
        self.y = 200
        self.hitbox = (11, 8)
        self.health = 3
        self.redraw = False


    def self.move(self, dx):
        self.x += dx
        self.redraw = True

    def draw(self, canvas):
        ...

    def resolve_laser(self, enemy_laser):
        ...


class Ufo:
    def __init__(self, pos, imgs=None):
        self.imgs = imgs
        self.pos = pos
        self.hitbox = (11, 8)
        self.health = 3
        self.redraw = True

    def draw(self, canvas):
        ...

    def resolve_laser(self, player_laser):
        ...

# %%
class EnemyLaser:
    def __init__(self, pos, t0, dy):
        self.pos = pos
        self.t0 = t0
        self.dy = dy

# %%
class Lasers:
    def __init__(self):
        self.laser = None  # player's laser
        self.lasers = {}  # enemy lasers

    def add_laser(self, pos, time, dy):
        self.lasers[pos] = (time, dy)

    def move_lasers(self, dt):
        lasers_to_remove = []
        for (pos, (t0, dy)) in self.lasers:
            if is_player_hit():
                player.hits +=1
                lasers_to_remove.append(pos)

        for pos in lasers_to_remove:
            self.lasers.pop(pos)

# %%
class Game:

    def __init__(self):
        self.game_state = 'init_screen'
 
    def new_game(self):
        self.t = 0
        self.score = 0
        self.lives = 3
        self.init
        self.enemies = Enemies()
        self.cannon = Cannon()

    def move(self, dx):
        self.cannon.move(dx)
        self.advance_time(1)

    def spawn_lasers(self):
        '''spawn new player laser if possible'''

    def spawn_enemy_lasers():
        ...

    def resolve(self):
        '''hand out damges and kill lasers'''

    def advance_time(self, dt):
        self.t += dt
        self._notify('render')
# Out:
#   Cell In[1], line 3
#     def __init__(self):
#                        ^
# _IncompleteInputError: incomplete input
