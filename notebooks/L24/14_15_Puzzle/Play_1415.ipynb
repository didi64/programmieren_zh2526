# %% [markdown]
# ### 14/15-Puzzle
#
# Wir implementieren das [14/15-Puzzle](https://de.wikipedia.org/wiki/15-Puzzle).
# **To Do**: `game.py` und `view.py` ergänzen.

# %%
import importlib
import grid_controller as C
import game as game
import view
importlib.reload(game)
importlib.reload(view)


callbacks = {'n': game.new_game,
             'mouse_down': game.move,
             }

view.init(game)
C.init(view.canvas, callbacks, view.grid_spec)
C.on_key_down('n')
C.show(debug=True)

# %% [markdown]
# ### Aufgabe${}^{\dagger}$
# Modifiziere die Funktion `game.move` so, dass man mehrere Kacheln auf einmal verschieben kann.
