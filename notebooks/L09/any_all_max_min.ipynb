# %% [markdown]
# ### Max, min, any , all

# %%
# Liste der Ortsname, die Ziffern enthalten
digits = '0123456789'
orte_mit_ziffern = []
for ort in orte:
    if any(d in ort for d in digits):
        orte_mit_ziffern.append(ort)
       
orte_mit_ziffern
