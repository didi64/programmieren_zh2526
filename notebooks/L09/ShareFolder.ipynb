# %% [markdown]
# ### Share-Folder einrichten
# Der Code in der nachstehenden Zelle richtet einen Ordner `studi@jlab:~/work/share` ein (nachfolgend kurz `share` genannt).
# Allerdngs ist der **email_prefix** und der **pin** anzupassen!
# Der `email_prefix` ist der Teil vor dem `@` deiner @edu.teko Emailadresse.
# Den `pin` werde ich noch verraten.
#
# Dieser Ordner kann dann dazu benutzt werden, Files mit mir auszutauschen.

# %%
from share import init_share
pin = 12345  # 12345 durch richtigen pin ersetzen
email_prefix = 'hans.muster'  # hans.muster durch deinen email-prefix ersetzen
init_share(email_prefix, pin)

# %% [markdown]
# ### Share-Folder benutzen
#
# - Zu teilende Files und Ordner in den `share`-Ordner verschieben/kopieren.
# - Im Jupyterlab-Terminal den Befehl
#   > $ `sync_share`
#
#   ausführen. Dies pushed den Inhalt des `share`-Ordners in ein Git-Repo, auf welches ich Zugriff habe.
#   Der Ordner `share` hat einen Unterordner `response`. Darin sind ggf. Notebooks von mir zu finden.
#
#
# **Aufgabe**:
# Erstellen ein neues Notebook mit etwas Text oder Code.
# Verschiebe dieses Notebook in den `share`-Ordner, öffne ein Jupyterlab-Terminal
# und führe darin den Befehl `sync_share` aus, um das Notebook mit mir zu teilen.
#
# Führe nach der Pause dann nochmals den Befehl `sync_share` aus.
# Dann sollte sich im Ordner `share/response` ein File `test.txt` befinden.
